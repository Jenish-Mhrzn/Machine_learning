# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenish-Mhrzn/Machine_learning/blob/main/Panda/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###PANDAS

# %%
import pandas as pd

data={
    "cars":["bmw","honda","lambo","mercedes"],
    "models":["2007","2008","2015","2024"],
    "passenger":["4","6","2","4"]
}
data
# Out:
# {'cars': ['bmw', 'honda', 'lambo', 'mercedes'],
#  'models': ['2007', '2008', '2015', '2024'],
#  'passenger': ['4', '6', '2', '4']}

# %%
#convert the data dictionary to dataframe
df=pd.DataFrame(data)
df
# Out:
#        cars models passenger
# 0       bmw   2007         4
# 1     honda   2008         6
# 2     lambo   2015         2
# 3  mercedes   2024         4

# %%
df.to_csv("/content/drive/MyDrive/Colab Notebooks/College/car_data.csv")

# %%
df=pd.read_csv("/content/car_data.csv")
df
# Out:
#    Unnamed: 0      cars  models  passenger
# 0           0       bmw    2007          4
# 1           1     honda    2008          6
# 2           2     lambo    2015          2
# 3           3  mercedes    2024          4

# %%
#create a dataframe with teo features calories and duration.
import pandas as pd
data={
    "calories":["420","500","390"],
    "duration":["50","60","45"]
}
data
# Out:
# {'calories': ['420', '500', '390'], 'duration': ['50', '60', '45']}

# %%
df=pd.DataFrame(data)
df
# Out:
#   calories duration
# 0      420       50
# 1      500       60
# 2      390       45

# %%
print(df.loc[1])
# Out:
# calories    500
# duration     60
# Name: 1, dtype: object

# %%
print(df.loc[[0, 1]])
# Out:
#   calories duration
# 0      420       50
# 1      500       60

# %%
#create a dataframe with indexing
import pandas as pd
data={
    "calories":["420","500","390"],
    "duration":["50","60","45"]
}
data
df= pd.DataFrame(data, index=["day1", "day2", "day3"])
df
# Out:
#      calories duration
# day1      420       50
# day2      500       60
# day3      390       45

# %%
print(df.loc[["day1", "day2"]])
# Out:
#      calories duration
# day1      420       50
# day2      500       60

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/College/pandas_dataset.csv")
df.head(5)
# Out:
#    Duration         Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01'    110       130     409.1
# 1        60  2020/12/02'    117       145     479.0
# 2        60  2020/12/03'    103       135     340.0
# 3        45  2020/12/04'    109       175     282.4
# 4        45  2020/12/05'    117       148     406.0

# %%
df["Date"]=df["Date"].replace("'", "", regex=True)
df.head(5)
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0

# %%
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
#return a dataset with no empty cells
#df.dropna() will remove epmty cells but will not chnage the dataframe
#If we want dataframe to be changed, use inplace=true
new_df=df.dropna()
new_df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
#another way of handling the null values is by replacing the null values with some other values
df_new2=df.fillna(130)
df_new2
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
#fill specific columns null value
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df["Calories"].fillna(130, inplace=True)
df
# Out:
# <ipython-input-32-f5e9811617e0>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(130, inplace=True)
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# ...

# %%
#fill null values with mean, median or mode
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/College/pandas_dataset.csv")
x=df["Calories"].mean()
df["Calories"]=df["Calories"].fillna(x)
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130    409.10
# 1         60  2020/12/02'    117       145    479.00
# 2         60  2020/12/03'    103       135    340.00
# 3         45  2020/12/04'    109       175    282.40
# 4         45  2020/12/05'    117       148    406.00
# 5         60  2020/12/06'    102       127    300.00
# 6         60  2020/12/07'    110       136    374.00
# 7        450  2020/12/08'    104       134    253.30
# 8         30  2020/12/09'    109       133    195.10
# 9         60  2020/12/10'     98       124    269.00
# 10        60  2020/12/11'    103       147    329.30
# 11        60  2020/12/12'    100       120    250.70
# 12        60  2020/12/12'    100       120    250.70
# 13        60  2020/12/13'    106       128    345.30
# 14        60  2020/12/14'    104       132    379.30
# 15        60  2020/12/15'     98       123    275.00
# 16        60  2020/12/16'     98       120    215.20
# ...
